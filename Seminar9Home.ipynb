# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6714     -118.29     34.01                39.0        751.0           207.0
# 4252     -118.00     33.82                24.0       3002.0           644.0
# 240      -116.50     33.69                20.0       4810.0          1074.0
# 12355    -121.53     38.61                 5.0       8149.0          1913.0
# 7796     -118.39     34.09                41.0        730.0           126.0
#
#        population  households  median_income  median_house_value
# 6714       1010.0       231.0         1.6036            137500.0
# 4252       1495.0       634.0         3.1087            202800.0
# 240        1304.0       740.0         2.2500            248100.0
# 12355      2933.0      1616.0         3.6788            178800.0
# 7796        230.0       125.0         4.3214            500001.0

# %% [markdown]
# Задача 40: Работать с файлом california_housing_train.csv, который находится в папке sample_data. Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
df[df['population'] < 500].median_house_value.mean().round()
# Out:
# 206683.84

# %% [markdown]
# Задача 42: Узнать какая максимальная households в зоне минимального значения population.

# %%
df[df['population'] == df['population'].min()].households.max()
# Out:
# 4.0
